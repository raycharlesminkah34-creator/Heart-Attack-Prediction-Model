# %%
import pandas as pd
import numpy as np
import matplotlib as plt
pd.set_option('display.max_columns', None)

try:
    df = pd.read_csv("heart_attack_dataset (1).csv")
except FileNotFoundError:
    print("File not found")

# %%
df.head(10)
# Out:
#    Age  Gender  Cholesterol  BloodPressure  HeartRate   BMI  Smoker  Diabetes  \
# 0   31    Male          194            162         71  22.9       0         1
# 1   69    Male          208            148         93  33.9       1         1
# 2   34  Female          132            161         94  34.0       0         0
# 3   53    Male          268            134         91  35.0       0         1
# 4   57  Female          203            140         75  30.1       0         1
# 5   41    Male          158            154         72  38.7       0         1
# 6   45  Female          237            168        114  21.7       0         0
# 7   61  Female          218            113        115  23.1       0         1
# 8   45    Male          216            114         72  24.8       0         1
# 9   30    Male          143            130         91  24.7       1         1
#
#    Hypertension  FamilyHistory  PhysicalActivity  AlcoholConsumption  \
# ...

# %%
df.shape
# Out:
# (372974, 32)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 372974 entries, 0 to 372973
# Data columns (total 32 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   Age                    372974 non-null  int64
#  1   Gender                 372974 non-null  str
#  2   Cholesterol            372974 non-null  int64
#  3   BloodPressure          372974 non-null  int64
#  4   HeartRate              372974 non-null  int64
#  5   BMI                    372974 non-null  float64
#  6   Smoker                 372974 non-null  int64
#  7   Diabetes               372974 non-null  int64
#  8   Hypertension           372974 non-null  int64
#  9   FamilyHistory          372974 non-null  int64
#  10  PhysicalActivity       372974 non-null  int64
#  11  AlcoholConsumption     372974 non-null  int64
#  12  Diet                   372974 non-null  str
#  13  StressLevel            372974 non-null  int64
# ...

# %%
df["Gender"].dtype
# Out:
# <StringDtype(na_value=nan)>

# %%
df.describe()
# Out:
#                  Age    Cholesterol  BloodPressure      HeartRate  \
# count  372974.000000  372974.000000  372974.000000  372974.000000
# mean       56.975151     199.455844     134.508234      89.495043
# std        15.867016      57.723381      25.984528      17.342658
# min        30.000000     100.000000      90.000000      60.000000
# 25%        43.000000     149.000000     112.000000      74.000000
# 50%        57.000000     199.000000     134.000000      89.000000
# 75%        71.000000     249.000000     157.000000     105.000000
# max        84.000000     299.000000     179.000000     119.000000
#
#                  BMI         Smoker       Diabetes   Hypertension  \
# count  372974.000000  372974.000000  372974.000000  372974.000000
# mean       29.006733       0.499225       0.500987       0.500973
# std         6.345460       0.500000       0.500000       0.500000
# min        18.000000       0.000000       0.000000       0.000000
# ...

# %%
cont_col = [col for col in df.columns if df[col].nunique() != 2]
for col in cont_col:
    zero_col = (df[col] == 0).sum()
    pct_zero = (zero_col / len(df)) * 100
    print(f"{col}: {pct_zero}%")
# Out:
# Age: 0.0%
# Cholesterol: 0.0%
# BloodPressure: 0.0%
# HeartRate: 0.0%
# BMI: 0.0%
# PhysicalActivity: 14.243620198726989%
# AlcoholConsumption: 19.981017443575155%
# Diet: 0.0%
# StressLevel: 0.0%
# Ethnicity: 0.0%
# Income: 0.0%
# EducationLevel: 0.0%
# ChestPainType: 0.0%
# ECGResults: 0.0%
# MaxHeartRate: 0.0%
# ST_Depression: 0.10778231190377882%
# Slope: 0.0%
# NumberOfMajorVessels: 25.027481808383428%
# Thalassemia: 0.0%
# Residence: 0.0%
# EmploymentStatus: 0.0%
# MaritalStatus: 0.0%

# %% [markdown]
# ### Observation
# -No missing values
# -few outliers, nothing alarming(most parameters seemed to be within reference range)
# -All zero values were checked and rechecked, and all seem valid

# %%
#Convert type str to object in cat variables
str_cols = df.select_dtypes(include="string").columns
df[str_cols] = df[str_cols].astype(object)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 372974 entries, 0 to 372973
# Data columns (total 32 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   Age                    372974 non-null  int64
#  1   Gender                 372974 non-null  object
#  2   Cholesterol            372974 non-null  int64
#  3   BloodPressure          372974 non-null  int64
#  4   HeartRate              372974 non-null  int64
#  5   BMI                    372974 non-null  float64
#  6   Smoker                 372974 non-null  int64
#  7   Diabetes               372974 non-null  int64
#  8   Hypertension           372974 non-null  int64
#  9   FamilyHistory          372974 non-null  int64
#  10  PhysicalActivity       372974 non-null  int64
#  11  AlcoholConsumption     372974 non-null  int64
#  12  Diet                   372974 non-null  object
#  13  StressLevel            372974 non-null  int64
# ...

# %%
#Data type grouping 
binary_cols = [col for col in df.columns if df[col].nunique() == 2]
cat_cols = [col for col in df.columns if (col not in binary_cols) & (col not in continuous_cols) & (col != "Outcome")]
continuous_cols = [col for col in df.columns if df[col].nunique() > 25]

# %%
binary_maps = {
    'Gender': {"Male": 1, "Female": 0},
    'Medication': {"Yes": 1, "No": 0},
    'ExerciseInducedAngina': {"Yes": 1, "No": 0},
    'Outcome': {"No Heart Attack": 0, "Heart Attack": 1}
    
}

# %%
#Binary Encoding
for col, mapping in binary_maps.items():
    df[col] = df[col].map(mapping)
# Out:
#    Age  Gender  Cholesterol  BloodPressure  HeartRate   BMI  Smoker  Diabetes  \
# 0   31     NaN          194            162         71  22.9       0         1
# 1   69     NaN          208            148         93  33.9       1         1
# 2   34     NaN          132            161         94  34.0       0         0
# 3   53     NaN          268            134         91  35.0       0         1
# 4   57     NaN          203            140         75  30.1       0         1
#
#    Hypertension  FamilyHistory  PhysicalActivity  AlcoholConsumption  \
# 0             0              0                 6                   0
# 1             0              0                 1                   2
# 2             1              1                 1                   3
# 3             1              0                 6                   0
# 4             0              0                 4                   1
#
#         Diet  StressLevel Ethnicity  Income EducationLevel  Medication  \
# ...

# %%
df[]

# %%
#Binary Encoding
for col, mapping in binary_maps.items():
    df[col] = df[col].map(mapping)
df.head()
# Out:
#    Age  Gender  Cholesterol  BloodPressure  HeartRate   BMI  Smoker  Diabetes  \
# 0   31     NaN          194            162         71  22.9       0         1
# 1   69     NaN          208            148         93  33.9       1         1
# 2   34     NaN          132            161         94  34.0       0         0
# 3   53     NaN          268            134         91  35.0       0         1
# 4   57     NaN          203            140         75  30.1       0         1
#
#    Hypertension  FamilyHistory  PhysicalActivity  AlcoholConsumption  \
# 0             0              0                 6                   0
# 1             0              0                 1                   2
# 2             1              1                 1                   3
# 3             1              0                 6                   0
# 4             0              0                 4                   1
#
#         Diet  StressLevel Ethnicity  Income EducationLevel  Medication  \
# ...
